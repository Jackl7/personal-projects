# %%
## import packages
import pandas as pd
import numpy as np
import duckdb
import os

import matplotlib.pyplot as plt
# %matplotlib inline


print("packages imported")
# Out:
# im ready to wrangle!
